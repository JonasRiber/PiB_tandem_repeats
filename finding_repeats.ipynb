# %% [markdown]
# ### Finding repeats in the suffix tree

# %% [markdown]
# First lets load all the functions from the construction script and create a suffix_tree we can work on

# %%
from suffixtree_construction import *
from graphviz import Digraph

# %%
test_string = "tatat"
suffix_tree = SuffixTree(test_string)

s_list, df_list = suffix_tree.df_numbering()
print(f"suffix_list: {s_list} \ndf_list:     {df_list}")
# Out:
# suffix_list: [0, 2, 4, 1, 3, 5]
# df_list:     [0, 1, 2, 3, 4, 5]

# %%
suffix_tree.visualize()
# Out:
# Visualization saved as Suffix_tree_compressed.png

# %% [markdown]
# #### Stoye and gusfield
